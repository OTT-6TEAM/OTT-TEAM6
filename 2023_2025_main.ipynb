# %%
import requests
import time
import random
from concurrent.futures import ThreadPoolExecutor, as_completed
import pandas as pd
import os

# ============================================
# 0. 기본 설정
# ============================================
API_KEY = "e162c669fcbfdacee808cdff73d64f1a"
BASE_URL = "https://api.themoviedb.org/3"

# 반기(H1/H2) 기간 5개
PERIODS = [
    ("2023_H1", "2023-01-01", "2023-06-30"),
    ("2023_H2", "2023-07-01", "2023-12-31"),
    ("2024_H1", "2024-01-01", "2024-06-30"),
    ("2024_H2", "2024-07-01", "2024-12-31"),
    ("2025_H1", "2025-01-01", "2025-06-30"),
]

# discover에서 사용할 정렬 기준들
DISCOVER_SORT_OPTIONS = [
    "popularity.desc",
    "popularity.asc",
    "vote_count.desc",
    "vote_average.desc",  # + vote_count.gte를 같이 줄 예정
]

# 각 정렬 기준당 뽑을 페이지 수 (조절 가능)
PAGES_PER_SORT = 150   # 150 * 4 sort ≈ 600페이지/반기
MAX_DISCOVER_PAGE = 500    # TMDB 정책상 최대 500

# 상세 정보 수집 스레드 수
DETAIL_MAX_WORKERS = 15

# 최종 출력 CSV
OUTPUT_CSV = "tmdb_movies_2023_2025H1_full.csv"


# ============================================
# 공통: 안전한 요청 함수 (에러 + 레이트리밋 대응)
# ============================================
def safe_get(url, params, max_retries=3, base_wait=2):
    """
    requests.get에 레이트리밋(429) & 네트워크 오류 대비용 래퍼.
    - 429면 Retry-After 헤더 또는 base_wait초 대기 후 재시도
    - 그 외 에러는 점점 대기시간 늘리면서 재시도
    """
    for attempt in range(1, max_retries + 1):
        try:
            resp = requests.get(url, params=params, timeout=10)
            # 레이트 리밋
            if resp.status_code == 429:
                wait = int(resp.headers.get("Retry-After", base_wait))
                print(f"[RATE LIMIT] {wait}초 대기 후 재시도... (attempt={attempt})")
                time.sleep(wait)
                continue

            resp.raise_for_status()
            return resp

        except Exception as e:
            print(f"[REQUEST ERROR] attempt={attempt}, error={e}")
            if attempt == max_retries:
                return None
            # 점점 늘려서 대기
            time.sleep(base_wait * attempt)

    return None


# ============================================
# 1. 반기별 discover로 movie_id 모으기
# ============================================
def get_total_pages_for_period(start_date, end_date, sort_by):
    """
    해당 기간 + 정렬 기준으로 discover 호출해서 total_pages 확인
    """
    params = {
        "api_key": API_KEY,
        "language": "en-US",
        "sort_by": sort_by,
        "primary_release_date.gte": start_date,
        "primary_release_date.lte": end_date,
        "include_adult": "true",
        "include_video": "false",
        "page": 1,
    }
    # 평점 정렬일 때는 최소 투표 수 조건 살짝 추가해주면 이상치 덜함
    if sort_by.startswith("vote_average"):
        params["vote_count.gte"] = 20

    resp = safe_get(f"{BASE_URL}/discover/movie", params=params)
    if resp is None:
        return 0

    data = resp.json()
    return int(data.get("total_pages", 0))


def discover_ids_for_period(label, start_date, end_date):
    """
    한 반기(period)에 대해:
    - 여러 정렬 기준으로
    - 랜덤 페이지를 골라
    - movie_id를 최대한 많이 모은다.
    """
    collected_ids = set()

    print(f"\n===== [{label}] ID 수집 시작 =====")
    for sort_by in DISCOVER_SORT_OPTIONS:
        total_pages = get_total_pages_for_period(start_date, end_date, sort_by)
        if total_pages == 0:
            print(f"[{label}] sort_by={sort_by} total_pages=0 (건너뜀)")
            continue

        # TMDB 정책상 최대 500까지
        total_pages = min(total_pages, MAX_DISCOVER_PAGE)

        # 이 정렬 기준에서 사용할 페이지 리스트 (랜덤 샘플링)
        n_pages = min(PAGES_PER_SORT, total_pages)
        pages = random.sample(range(1, total_pages + 1), n_pages)

        print(f"[{label}] sort_by={sort_by}, total_pages={total_pages}, 샘플링 {n_pages}페이지")

        for page in pages:
            params = {
                "api_key": API_KEY,
                "language": "en-US",
                "sort_by": sort_by,
                "primary_release_date.gte": start_date,
                "primary_release_date.lte": end_date,
                "include_adult": "true",
                "include_video": "false",
                "page": page,
            }
            if sort_by.startswith("vote_average"):
                params["vote_count.gte"] = 20

            resp = safe_get(f"{BASE_URL}/discover/movie", params=params)
            if resp is None:
                print(f"[{label}] page={page} 요청 실패, 건너뜀")
                continue

            data = resp.json()
            results = data.get("results", [])
            for item in results:
                mid = item.get("id")
                if mid:
                    collected_ids.add(mid)

        print(f"[{label}] sort_by={sort_by} 완료, 누적 ID 수: {len(collected_ids)}")

    print(f"[{label}] 최종 유니크 ID 수: {len(collected_ids)}")
    return collected_ids


def collect_all_ids_for_periods():
    """
    PERIODS 전체에 대해 ID 모으고,
    최종 유니크 ID 리스트 반환
    """
    all_ids = set()
    period_id_dict = {}

    for label, start_date, end_date in PERIODS:
        ids = discover_ids_for_period(label, start_date, end_date)
        period_id_dict[label] = ids
        all_ids.update(ids)

    print("\n===== 전체 기간 기준 ID 요약 =====")
    for label, ids in period_id_dict.items():
        print(f"{label}: {len(ids)}개")
    print(f"전체 유니크 ID 개수: {len(all_ids)}")

    return list(all_ids)


# ============================================
# 2. 상세 정보 + credits + keywords + providers 수집
# ============================================
def join_list(items, key=None):
    """리스트를 '|'로 이어붙이는 유틸 함수"""
    if not items:
        return None
    if key:
        vals = [str(x.get(key, "")).strip() for x in items if x.get(key)]
    else:
        vals = [str(x).strip() for x in items if x]
    vals = [v for v in vals if v]
    return "|".join(vals) if vals else None


def parse_movie_to_row(data: dict, region: str = "KR") -> dict:
    """TMDB movie + credits + keywords + watch/providers 응답을
    표준 35컬럼 스키마 dict로 변환"""

    movie_id = data.get("id")
    imdb_id = data.get("imdb_id")
    title = data.get("title")
    original_title = data.get("original_title")
    original_language = data.get("original_language")
    overview = data.get("overview")
    tagline = data.get("tagline")
    homepage = data.get("homepage")
    status = data.get("status")
    release_date = data.get("release_date")
    runtime = data.get("runtime")
    adult = data.get("adult", False)
    budget = data.get("budget") or 0
    revenue = data.get("revenue") or 0
    vote_count = data.get("vote_count") or 0
    vote_average = data.get("vote_average") or 0.0
    popularity = data.get("popularity") or 0.0

    # release_year
    try:
        release_year = int(release_date[:4]) if release_date else None
    except Exception:
        release_year = None

    # roi
    roi = None
    if budget and revenue and budget > 0:
        roi = revenue / budget

    # 장르
    genres_list = data.get("genres", [])
    genres = join_list(genres_list, key="name")
    genre_ids_vals = [str(g.get("id")) for g in genres_list if g.get("id") is not None]
    genre_ids = "|".join(genre_ids_vals) if genre_ids_vals else None
    genre_count = len(genres_list) if genres_list else 0

    # 키워드
    keywords_data = data.get("keywords", {})
    keywords_list = keywords_data.get("keywords", [])
    keywords = join_list(keywords_list, key="name")
    keyword_count = len(keywords_list) if keywords_list else 0

    # 제작/국가/언어
    production_companies = join_list(data.get("production_companies", []), key="name")
    production_countries = join_list(data.get("production_countries", []), key="name")
    spoken_languages = join_list(data.get("spoken_languages", []), key="name")

    # 크레딧
    credits = data.get("credits", {})
    cast = credits.get("cast", [])
    crew = credits.get("crew", [])

    cast_sorted = sorted(cast, key=lambda x: x.get("order", 9999))
    top_cast_names = [c.get("name") for c in cast_sorted[:5] if c.get("name")]
    top_cast = "|".join(top_cast_names) if top_cast_names else None
    cast_count = len(cast) if cast else 0

    directors = [c.get("name") for c in crew if c.get("job") == "Director" and c.get("name")]
    director = "|".join(directors) if directors else None

    writers_list = [
        c.get("name")
        for c in crew
        if c.get("department") == "Writing" and c.get("name")
    ]
    writers = "|".join(sorted(set(writers_list))) if writers_list else None

    producers_list = [
        c.get("name")
        for c in crew
        if c.get("job") in ["Producer", "Executive Producer"] and c.get("name")
    ]
    producers = "|".join(sorted(set(producers_list))) if producers_list else None

    # OTT
    providers_data = data.get("watch/providers", {}).get("results", {})
    region_info = providers_data.get(region, {}) if providers_data else {}
    providers_flatrate = join_list(region_info.get("flatrate", []), key="provider_name")
    providers_rent = join_list(region_info.get("rent", []), key="provider_name")
    providers_buy = join_list(region_info.get("buy", []), key="provider_name")

    row = {
        "id": movie_id,
        "imdb_id": imdb_id,
        "title": title,
        "original_title": original_title,
        "original_language": original_language,
        "overview": overview,
        "tagline": tagline,
        "homepage": homepage,
        "status": status,
        "release_date": release_date,
        "release_year": release_year,
        "runtime": runtime,
        "adult": int(bool(adult)),
        "budget": budget,
        "revenue": revenue,
        "roi": roi,
        "vote_count": vote_count,
        "vote_average": vote_average,
        "popularity": popularity,
        "genres": genres,
        "genre_ids": genre_ids,
        "genre_count": genre_count,
        "keywords": keywords,
        "keyword_count": keyword_count,
        "production_companies": production_companies,
        "production_countries": production_countries,
        "spoken_languages": spoken_languages,
        "top_cast": top_cast,
        "director": director,
        "writers": writers,
        "producers": producers,
        "cast_count": cast_count,
        "providers_flatrate": providers_flatrate,
        "providers_rent": providers_rent,
        "providers_buy": providers_buy,
    }
    return row


def fetch_movie_detail(movie_id: int, region: str = "KR"):
    """단일 movie_id에 대해 상세 정보 요청"""
    params = {
        "api_key": API_KEY,
        "language": "en-US",
        "append_to_response": "credits,keywords,watch/providers",
    }
    resp = safe_get(f"{BASE_URL}/movie/{movie_id}", params=params)
    if resp is None:
        print(f"[ERROR] movie_id={movie_id} 요청 실패")
        return None

    try:
        data = resp.json()
        row = parse_movie_to_row(data, region=region)
        return row
    except Exception as e:
        print(f"[ERROR] movie_id={movie_id} 파싱 실패: {e}")
        return None


def collect_details_for_ids(movie_ids, max_workers=DETAIL_MAX_WORKERS):
    """
    movie_id 리스트에 대해 멀티스레드로 상세 정보 수집
    """
    rows = []
    total = len(movie_ids)
    print(f"\n===== 상세 정보 수집 시작 (총 {total}개) =====")

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(fetch_movie_detail, mid): mid for mid in movie_ids}

        for i, f in enumerate(as_completed(futures), start=1):
            mid = futures[f]
            result = f.result()
            if result is not None:
                rows.append(result)
            if i % 100 == 0 or i == total:
                print(f"[detail] {i}/{total} 처리 완료 (누적 유효 {len(rows)}개)")

    print(f"[detail] 최종 유효 레코드 수: {len(rows)}")
    return rows


# ============================================
# 3. 메인 파이프라인
# ============================================
def main():
    # 1) 반기별 discover로 ID 전부 모으기
    movie_ids = collect_all_ids_for_periods()
    print(f"\n[main] 전체 유니크 movie_id 개수: {len(movie_ids)}")

    # 필요하면 여기서 샘플만 뽑아서 테스트도 가능:
    # movie_ids = movie_ids[:2000]

    # 2) 멀티스레드로 상세 정보 수집
    rows = collect_details_for_ids(movie_ids, max_workers=DETAIL_MAX_WORKERS)

    # 3) DataFrame으로 만들고 CSV 저장
    df = pd.DataFrame(rows)
    print(df.head())
    print(df.shape)
    print(df.columns)

    df.to_csv(OUTPUT_CSV, index=False, encoding="utf-8-sig")
    print(f'[main] "{OUTPUT_CSV}" 저장 완료')


if __name__ == "__main__":
    main()
# Out:
# ===== [2023_H1] ID 수집 시작 =====
# [2023_H1] sort_by=popularity.desc, total_pages=500, 샘플링 150페이지
# [2023_H1] sort_by=popularity.desc 완료, 누적 ID 수: 3000
# [2023_H1] sort_by=popularity.asc, total_pages=500, 샘플링 150페이지
# [2023_H1] sort_by=popularity.asc 완료, 누적 ID 수: 6000
# [2023_H1] sort_by=vote_count.desc, total_pages=500, 샘플링 150페이지
# [2023_H1] sort_by=vote_count.desc 완료, 누적 ID 수: 8188
# [2023_H1] sort_by=vote_average.desc, total_pages=41, 샘플링 41페이지
# [2023_H1] sort_by=vote_average.desc 완료, 누적 ID 수: 8563
# [2023_H1] 최종 유니크 ID 수: 8563
#
# ===== [2023_H2] ID 수집 시작 =====
# [2023_H2] sort_by=popularity.desc, total_pages=500, 샘플링 150페이지
# [2023_H2] sort_by=popularity.desc 완료, 누적 ID 수: 3000
# [2023_H2] sort_by=popularity.asc, total_pages=500, 샘플링 150페이지
# [2023_H2] sort_by=popularity.asc 완료, 누적 ID 수: 6000
# [2023_H2] sort_by=vote_count.desc, total_pages=500, 샘플링 150페이지
# [2023_H2] sort_by=vote_count.desc 완료, 누적 ID 수: 8231
# [2023_H2] sort_by=vote_average.desc, total_pages=47, 샘플링 47페이지
# [2023_H2] sort_by=vote_average.desc 완료, 누적 ID 수: 8665
# [2023_H2] 최종 유니크 ID 수: 8665
#
# ===== [2024_H1] ID 수집 시작 =====
# [2024_H1] sort_by=popularity.desc, total_pages=500, 샘플링 150페이지
# [2024_H1] sort_by=popularity.desc 완료, 누적 ID 수: 3000
# [2024_H1] sort_by=popularity.asc, total_pages=500, 샘플링 150페이지
# [2024_H1] sort_by=popularity.asc 완료, 누적 ID 수: 6000
# [2024_H1] sort_by=vote_count.desc, total_pages=500, 샘플링 150페이지
# [2024_H1] sort_by=vote_count.desc 완료, 누적 ID 수: 8296
# [2024_H1] sort_by=vote_average.desc, total_pages=33, 샘플링 33페이지
# [2024_H1] sort_by=vote_average.desc 완료, 누적 ID 수: 8601
# [2024_H1] 최종 유니크 ID 수: 8601
#
# ===== [2024_H2] ID 수집 시작 =====
# [2024_H2] sort_by=popularity.desc, total_pages=500, 샘플링 150페이지
# [2024_H2] sort_by=popularity.desc 완료, 누적 ID 수: 2999
# [2024_H2] sort_by=popularity.asc, total_pages=500, 샘플링 150페이지
# [2024_H2] sort_by=popularity.asc 완료, 누적 ID 수: 5999
# [2024_H2] sort_by=vote_count.desc, total_pages=500, 샘플링 150페이지
# [2024_H2] sort_by=vote_count.desc 완료, 누적 ID 수: 8274
# [2024_H2] sort_by=vote_average.desc, total_pages=36, 샘플링 36페이지
# [2024_H2] sort_by=vote_average.desc 완료, 누적 ID 수: 8674
# [2024_H2] 최종 유니크 ID 수: 8674
#
# ===== [2025_H1] ID 수집 시작 =====
# [2025_H1] sort_by=popularity.desc, total_pages=500, 샘플링 150페이지
# [2025_H1] sort_by=popularity.desc 완료, 누적 ID 수: 2998
# [2025_H1] sort_by=popularity.asc, total_pages=500, 샘플링 150페이지
# [2025_H1] sort_by=popularity.asc 완료, 누적 ID 수: 5997
# [2025_H1] sort_by=vote_count.desc, total_pages=500, 샘플링 150페이지
# [2025_H1] sort_by=vote_count.desc 완료, 누적 ID 수: 8279
# [2025_H1] sort_by=vote_average.desc, total_pages=24, 샘플링 24페이지
# [2025_H1] sort_by=vote_average.desc 완료, 누적 ID 수: 8506
# [2025_H1] 최종 유니크 ID 수: 8506
#
# ===== 전체 기간 기준 ID 요약 =====
# 2023_H1: 8563개
# 2023_H2: 8665개
# 2024_H1: 8601개
# 2024_H2: 8674개
# 2025_H1: 8506개
# 전체 유니크 ID 개수: 43009
#
# [main] 전체 유니크 movie_id 개수: 43009
#
# ===== 상세 정보 수집 시작 (총 43009개) =====
# [detail] 100/43009 처리 완료 (누적 유효 100개)
# [detail] 200/43009 처리 완료 (누적 유효 200개)
# [detail] 300/43009 처리 완료 (누적 유효 300개)
# [detail] 400/43009 처리 완료 (누적 유효 400개)
# [detail] 500/43009 처리 완료 (누적 유효 500개)
# [detail] 600/43009 처리 완료 (누적 유효 600개)
# [detail] 700/43009 처리 완료 (누적 유효 700개)
# [detail] 800/43009 처리 완료 (누적 유효 800개)
# [detail] 900/43009 처리 완료 (누적 유효 900개)
# [detail] 1000/43009 처리 완료 (누적 유효 1000개)
# [detail] 1100/43009 처리 완료 (누적 유효 1100개)
# [detail] 1200/43009 처리 완료 (누적 유효 1200개)
# [detail] 1300/43009 처리 완료 (누적 유효 1300개)
# [detail] 1400/43009 처리 완료 (누적 유효 1400개)
# [detail] 1500/43009 처리 완료 (누적 유효 1500개)
# [detail] 1600/43009 처리 완료 (누적 유효 1600개)
# [detail] 1700/43009 처리 완료 (누적 유효 1700개)
# [detail] 1800/43009 처리 완료 (누적 유효 1800개)
# [detail] 1900/43009 처리 완료 (누적 유효 1900개)
# [detail] 2000/43009 처리 완료 (누적 유효 2000개)
# [detail] 2100/43009 처리 완료 (누적 유효 2100개)
# [detail] 2200/43009 처리 완료 (누적 유효 2200개)
# [detail] 2300/43009 처리 완료 (누적 유효 2300개)
# [detail] 2400/43009 처리 완료 (누적 유효 2400개)
# [detail] 2500/43009 처리 완료 (누적 유효 2500개)
# [detail] 2600/43009 처리 완료 (누적 유효 2600개)
# [detail] 2700/43009 처리 완료 (누적 유효 2700개)
# [detail] 2800/43009 처리 완료 (누적 유효 2800개)
# [detail] 2900/43009 처리 완료 (누적 유효 2900개)
# [detail] 3000/43009 처리 완료 (누적 유효 3000개)
# [detail] 3100/43009 처리 완료 (누적 유효 3100개)
# [detail] 3200/43009 처리 완료 (누적 유효 3200개)
# [detail] 3300/43009 처리 완료 (누적 유효 3300개)
# [detail] 3400/43009 처리 완료 (누적 유효 3400개)
# [detail] 3500/43009 처리 완료 (누적 유효 3500개)
# [detail] 3600/43009 처리 완료 (누적 유효 3600개)
# [detail] 3700/43009 처리 완료 (누적 유효 3700개)
# [detail] 3800/43009 처리 완료 (누적 유효 3800개)
# [detail] 3900/43009 처리 완료 (누적 유효 3900개)
# [detail] 4000/43009 처리 완료 (누적 유효 4000개)
# [detail] 4100/43009 처리 완료 (누적 유효 4100개)
# [detail] 4200/43009 처리 완료 (누적 유효 4200개)
# [detail] 4300/43009 처리 완료 (누적 유효 4300개)
# [detail] 4400/43009 처리 완료 (누적 유효 4400개)
# [detail] 4500/43009 처리 완료 (누적 유효 4500개)
# [detail] 4600/43009 처리 완료 (누적 유효 4600개)
# [detail] 4700/43009 처리 완료 (누적 유효 4700개)
# [detail] 4800/43009 처리 완료 (누적 유효 4800개)
# [detail] 4900/43009 처리 완료 (누적 유효 4900개)
# [detail] 5000/43009 처리 완료 (누적 유효 5000개)
# [detail] 5100/43009 처리 완료 (누적 유효 5100개)
# [detail] 5200/43009 처리 완료 (누적 유효 5200개)
# [detail] 5300/43009 처리 완료 (누적 유효 5300개)
# [detail] 5400/43009 처리 완료 (누적 유효 5400개)
# [detail] 5500/43009 처리 완료 (누적 유효 5500개)
# [detail] 5600/43009 처리 완료 (누적 유효 5600개)
# [detail] 5700/43009 처리 완료 (누적 유효 5700개)
# [detail] 5800/43009 처리 완료 (누적 유효 5800개)
# [detail] 5900/43009 처리 완료 (누적 유효 5900개)
# [detail] 6000/43009 처리 완료 (누적 유효 6000개)
# [detail] 6100/43009 처리 완료 (누적 유효 6100개)
# [detail] 6200/43009 처리 완료 (누적 유효 6200개)
# [detail] 6300/43009 처리 완료 (누적 유효 6300개)
# [detail] 6400/43009 처리 완료 (누적 유효 6400개)
# [detail] 6500/43009 처리 완료 (누적 유효 6500개)
# [detail] 6600/43009 처리 완료 (누적 유효 6600개)
# [detail] 6700/43009 처리 완료 (누적 유효 6700개)
# [detail] 6800/43009 처리 완료 (누적 유효 6800개)
# [detail] 6900/43009 처리 완료 (누적 유효 6900개)
# [detail] 7000/43009 처리 완료 (누적 유효 7000개)
# [detail] 7100/43009 처리 완료 (누적 유효 7100개)
# [detail] 7200/43009 처리 완료 (누적 유효 7200개)
# [detail] 7300/43009 처리 완료 (누적 유효 7300개)
# [detail] 7400/43009 처리 완료 (누적 유효 7400개)
# [detail] 7500/43009 처리 완료 (누적 유효 7500개)
# [detail] 7600/43009 처리 완료 (누적 유효 7600개)
# [detail] 7700/43009 처리 완료 (누적 유효 7700개)
# [detail] 7800/43009 처리 완료 (누적 유효 7800개)
# [detail] 7900/43009 처리 완료 (누적 유효 7900개)
# [detail] 8000/43009 처리 완료 (누적 유효 8000개)
# [detail] 8100/43009 처리 완료 (누적 유효 8100개)
# [detail] 8200/43009 처리 완료 (누적 유효 8200개)
# [detail] 8300/43009 처리 완료 (누적 유효 8300개)
# [detail] 8400/43009 처리 완료 (누적 유효 8400개)
# [detail] 8500/43009 처리 완료 (누적 유효 8500개)
# [detail] 8600/43009 처리 완료 (누적 유효 8600개)
# [detail] 8700/43009 처리 완료 (누적 유효 8700개)
# [detail] 8800/43009 처리 완료 (누적 유효 8800개)
# [detail] 8900/43009 처리 완료 (누적 유효 8900개)
# [detail] 9000/43009 처리 완료 (누적 유효 9000개)
# [detail] 9100/43009 처리 완료 (누적 유효 9100개)
# [detail] 9200/43009 처리 완료 (누적 유효 9200개)
# [detail] 9300/43009 처리 완료 (누적 유효 9300개)
# [detail] 9400/43009 처리 완료 (누적 유효 9400개)
# [detail] 9500/43009 처리 완료 (누적 유효 9500개)
# [detail] 9600/43009 처리 완료 (누적 유효 9600개)
# [detail] 9700/43009 처리 완료 (누적 유효 9700개)
# [detail] 9800/43009 처리 완료 (누적 유효 9800개)
# [detail] 9900/43009 처리 완료 (누적 유효 9900개)
# [detail] 10000/43009 처리 완료 (누적 유효 10000개)
# [detail] 10100/43009 처리 완료 (누적 유효 10100개)
# [detail] 10200/43009 처리 완료 (누적 유효 10200개)
# [detail] 10300/43009 처리 완료 (누적 유효 10300개)
# [detail] 10400/43009 처리 완료 (누적 유효 10400개)
# [detail] 10500/43009 처리 완료 (누적 유효 10500개)
# [detail] 10600/43009 처리 완료 (누적 유효 10600개)
# [detail] 10700/43009 처리 완료 (누적 유효 10700개)
# [detail] 10800/43009 처리 완료 (누적 유효 10800개)
# [detail] 10900/43009 처리 완료 (누적 유효 10900개)
# [detail] 11000/43009 처리 완료 (누적 유효 11000개)
# [detail] 11100/43009 처리 완료 (누적 유효 11100개)
# [detail] 11200/43009 처리 완료 (누적 유효 11200개)
# [detail] 11300/43009 처리 완료 (누적 유효 11300개)
# [detail] 11400/43009 처리 완료 (누적 유효 11400개)
# [detail] 11500/43009 처리 완료 (누적 유효 11500개)
# [detail] 11600/43009 처리 완료 (누적 유효 11600개)
# [detail] 11700/43009 처리 완료 (누적 유효 11700개)
# [detail] 11800/43009 처리 완료 (누적 유효 11800개)
# [detail] 11900/43009 처리 완료 (누적 유효 11900개)
# [detail] 12000/43009 처리 완료 (누적 유효 12000개)
# [detail] 12100/43009 처리 완료 (누적 유효 12100개)
# [detail] 12200/43009 처리 완료 (누적 유효 12200개)
# [detail] 12300/43009 처리 완료 (누적 유효 12300개)
# [detail] 12400/43009 처리 완료 (누적 유효 12400개)
# [detail] 12500/43009 처리 완료 (누적 유효 12500개)
# [detail] 12600/43009 처리 완료 (누적 유효 12600개)
# [detail] 12700/43009 처리 완료 (누적 유효 12700개)
# [detail] 12800/43009 처리 완료 (누적 유효 12800개)
# [detail] 12900/43009 처리 완료 (누적 유효 12900개)
# [detail] 13000/43009 처리 완료 (누적 유효 13000개)
# [detail] 13100/43009 처리 완료 (누적 유효 13100개)
# [detail] 13200/43009 처리 완료 (누적 유효 13200개)
# [detail] 13300/43009 처리 완료 (누적 유효 13300개)
# [detail] 13400/43009 처리 완료 (누적 유효 13400개)
# [detail] 13500/43009 처리 완료 (누적 유효 13500개)
# [detail] 13600/43009 처리 완료 (누적 유효 13600개)
# [detail] 13700/43009 처리 완료 (누적 유효 13700개)
# [detail] 13800/43009 처리 완료 (누적 유효 13800개)
# [detail] 13900/43009 처리 완료 (누적 유효 13900개)
# [detail] 14000/43009 처리 완료 (누적 유효 14000개)
# [detail] 14100/43009 처리 완료 (누적 유효 14100개)
# [detail] 14200/43009 처리 완료 (누적 유효 14200개)
# [detail] 14300/43009 처리 완료 (누적 유효 14300개)
# [detail] 14400/43009 처리 완료 (누적 유효 14400개)
# [detail] 14500/43009 처리 완료 (누적 유효 14500개)
# [detail] 14600/43009 처리 완료 (누적 유효 14600개)
# [detail] 14700/43009 처리 완료 (누적 유효 14700개)
# [detail] 14800/43009 처리 완료 (누적 유효 14800개)
# [detail] 14900/43009 처리 완료 (누적 유효 14900개)
# [detail] 15000/43009 처리 완료 (누적 유효 15000개)
# [detail] 15100/43009 처리 완료 (누적 유효 15100개)
# [detail] 15200/43009 처리 완료 (누적 유효 15200개)
# [detail] 15300/43009 처리 완료 (누적 유효 15300개)
# [detail] 15400/43009 처리 완료 (누적 유효 15400개)
# [detail] 15500/43009 처리 완료 (누적 유효 15500개)
# [detail] 15600/43009 처리 완료 (누적 유효 15600개)
# [detail] 15700/43009 처리 완료 (누적 유효 15700개)
# [detail] 15800/43009 처리 완료 (누적 유효 15800개)
# [detail] 15900/43009 처리 완료 (누적 유효 15900개)
# [detail] 16000/43009 처리 완료 (누적 유효 16000개)
# [detail] 16100/43009 처리 완료 (누적 유효 16100개)
# [detail] 16200/43009 처리 완료 (누적 유효 16200개)
# [detail] 16300/43009 처리 완료 (누적 유효 16300개)
# [detail] 16400/43009 처리 완료 (누적 유효 16400개)
# [detail] 16500/43009 처리 완료 (누적 유효 16500개)
# [detail] 16600/43009 처리 완료 (누적 유효 16600개)
# [detail] 16700/43009 처리 완료 (누적 유효 16700개)
# [detail] 16800/43009 처리 완료 (누적 유효 16800개)
# [detail] 16900/43009 처리 완료 (누적 유효 16900개)
# [detail] 17000/43009 처리 완료 (누적 유효 17000개)
# [detail] 17100/43009 처리 완료 (누적 유효 17100개)
# [detail] 17200/43009 처리 완료 (누적 유효 17200개)
# [detail] 17300/43009 처리 완료 (누적 유효 17300개)
# [detail] 17400/43009 처리 완료 (누적 유효 17400개)
# [detail] 17500/43009 처리 완료 (누적 유효 17500개)
# [detail] 17600/43009 처리 완료 (누적 유효 17600개)
# [detail] 17700/43009 처리 완료 (누적 유효 17700개)
# [detail] 17800/43009 처리 완료 (누적 유효 17800개)
# [detail] 17900/43009 처리 완료 (누적 유효 17900개)
# [detail] 18000/43009 처리 완료 (누적 유효 18000개)
# [detail] 18100/43009 처리 완료 (누적 유효 18100개)
# [detail] 18200/43009 처리 완료 (누적 유효 18200개)
# [detail] 18300/43009 처리 완료 (누적 유효 18300개)
# [detail] 18400/43009 처리 완료 (누적 유효 18400개)
# [detail] 18500/43009 처리 완료 (누적 유효 18500개)
# [detail] 18600/43009 처리 완료 (누적 유효 18600개)
# [detail] 18700/43009 처리 완료 (누적 유효 18700개)
# [detail] 18800/43009 처리 완료 (누적 유효 18800개)
# [detail] 18900/43009 처리 완료 (누적 유효 18900개)
# [detail] 19000/43009 처리 완료 (누적 유효 19000개)
# [detail] 19100/43009 처리 완료 (누적 유효 19100개)
# [detail] 19200/43009 처리 완료 (누적 유효 19200개)
# [detail] 19300/43009 처리 완료 (누적 유효 19300개)
# [detail] 19400/43009 처리 완료 (누적 유효 19400개)
# [detail] 19500/43009 처리 완료 (누적 유효 19500개)
# [detail] 19600/43009 처리 완료 (누적 유효 19600개)
# [detail] 19700/43009 처리 완료 (누적 유효 19700개)
# [detail] 19800/43009 처리 완료 (누적 유효 19800개)
# [detail] 19900/43009 처리 완료 (누적 유효 19900개)
# [detail] 20000/43009 처리 완료 (누적 유효 20000개)
# [detail] 20100/43009 처리 완료 (누적 유효 20100개)
# [detail] 20200/43009 처리 완료 (누적 유효 20200개)
# [detail] 20300/43009 처리 완료 (누적 유효 20300개)
# [detail] 20400/43009 처리 완료 (누적 유효 20400개)
# [detail] 20500/43009 처리 완료 (누적 유효 20500개)
# [detail] 20600/43009 처리 완료 (누적 유효 20600개)
# [detail] 20700/43009 처리 완료 (누적 유효 20700개)
# [detail] 20800/43009 처리 완료 (누적 유효 20800개)
# [detail] 20900/43009 처리 완료 (누적 유효 20900개)
# [detail] 21000/43009 처리 완료 (누적 유효 21000개)
# [detail] 21100/43009 처리 완료 (누적 유효 21100개)
# [detail] 21200/43009 처리 완료 (누적 유효 21200개)
# [detail] 21300/43009 처리 완료 (누적 유효 21300개)
# [detail] 21400/43009 처리 완료 (누적 유효 21400개)
# [detail] 21500/43009 처리 완료 (누적 유효 21500개)
# [detail] 21600/43009 처리 완료 (누적 유효 21600개)
# [detail] 21700/43009 처리 완료 (누적 유효 21700개)
# [detail] 21800/43009 처리 완료 (누적 유효 21800개)
# [detail] 21900/43009 처리 완료 (누적 유효 21900개)
# [detail] 22000/43009 처리 완료 (누적 유효 22000개)
# [detail] 22100/43009 처리 완료 (누적 유효 22100개)
# [detail] 22200/43009 처리 완료 (누적 유효 22200개)
# [detail] 22300/43009 처리 완료 (누적 유효 22300개)
# [detail] 22400/43009 처리 완료 (누적 유효 22400개)
# [detail] 22500/43009 처리 완료 (누적 유효 22500개)
# [detail] 22600/43009 처리 완료 (누적 유효 22600개)
# [detail] 22700/43009 처리 완료 (누적 유효 22700개)
# [detail] 22800/43009 처리 완료 (누적 유효 22800개)
# [detail] 22900/43009 처리 완료 (누적 유효 22900개)
# [detail] 23000/43009 처리 완료 (누적 유효 23000개)
# [detail] 23100/43009 처리 완료 (누적 유효 23100개)
# [detail] 23200/43009 처리 완료 (누적 유효 23200개)
# [detail] 23300/43009 처리 완료 (누적 유효 23300개)
# [detail] 23400/43009 처리 완료 (누적 유효 23400개)
# [detail] 23500/43009 처리 완료 (누적 유효 23500개)
# [detail] 23600/43009 처리 완료 (누적 유효 23600개)
# [detail] 23700/43009 처리 완료 (누적 유효 23700개)
# [detail] 23800/43009 처리 완료 (누적 유효 23800개)
# [detail] 23900/43009 처리 완료 (누적 유효 23900개)
# [detail] 24000/43009 처리 완료 (누적 유효 24000개)
# [detail] 24100/43009 처리 완료 (누적 유효 24100개)
# [detail] 24200/43009 처리 완료 (누적 유효 24200개)
# [detail] 24300/43009 처리 완료 (누적 유효 24300개)
# [detail] 24400/43009 처리 완료 (누적 유효 24400개)
# [detail] 24500/43009 처리 완료 (누적 유효 24500개)
# [detail] 24600/43009 처리 완료 (누적 유효 24600개)
# [detail] 24700/43009 처리 완료 (누적 유효 24700개)
# [detail] 24800/43009 처리 완료 (누적 유효 24800개)
# [detail] 24900/43009 처리 완료 (누적 유효 24900개)
# [detail] 25000/43009 처리 완료 (누적 유효 25000개)
# [detail] 25100/43009 처리 완료 (누적 유효 25100개)
# [detail] 25200/43009 처리 완료 (누적 유효 25200개)
# [detail] 25300/43009 처리 완료 (누적 유효 25300개)
# [detail] 25400/43009 처리 완료 (누적 유효 25400개)
# [detail] 25500/43009 처리 완료 (누적 유효 25500개)
# [detail] 25600/43009 처리 완료 (누적 유효 25600개)
# [detail] 25700/43009 처리 완료 (누적 유효 25700개)
# [detail] 25800/43009 처리 완료 (누적 유효 25800개)
# [detail] 25900/43009 처리 완료 (누적 유효 25900개)
# [detail] 26000/43009 처리 완료 (누적 유효 26000개)
# [detail] 26100/43009 처리 완료 (누적 유효 26100개)
# [detail] 26200/43009 처리 완료 (누적 유효 26200개)
# [detail] 26300/43009 처리 완료 (누적 유효 26300개)
# [detail] 26400/43009 처리 완료 (누적 유효 26400개)
# [detail] 26500/43009 처리 완료 (누적 유효 26500개)
# [detail] 26600/43009 처리 완료 (누적 유효 26600개)
# [detail] 26700/43009 처리 완료 (누적 유효 26700개)
# [detail] 26800/43009 처리 완료 (누적 유효 26800개)
# [detail] 26900/43009 처리 완료 (누적 유효 26900개)
# [detail] 27000/43009 처리 완료 (누적 유효 27000개)
# [detail] 27100/43009 처리 완료 (누적 유효 27100개)
# [detail] 27200/43009 처리 완료 (누적 유효 27200개)
# [detail] 27300/43009 처리 완료 (누적 유효 27300개)
# [detail] 27400/43009 처리 완료 (누적 유효 27400개)
# [detail] 27500/43009 처리 완료 (누적 유효 27500개)
# [detail] 27600/43009 처리 완료 (누적 유효 27600개)
# [detail] 27700/43009 처리 완료 (누적 유효 27700개)
# [detail] 27800/43009 처리 완료 (누적 유효 27800개)
# [detail] 27900/43009 처리 완료 (누적 유효 27900개)
# [detail] 28000/43009 처리 완료 (누적 유효 28000개)
# [detail] 28100/43009 처리 완료 (누적 유효 28100개)
# [detail] 28200/43009 처리 완료 (누적 유효 28200개)
# [detail] 28300/43009 처리 완료 (누적 유효 28300개)
# [detail] 28400/43009 처리 완료 (누적 유효 28400개)
# [detail] 28500/43009 처리 완료 (누적 유효 28500개)
# [detail] 28600/43009 처리 완료 (누적 유효 28600개)
# [detail] 28700/43009 처리 완료 (누적 유효 28700개)
# [detail] 28800/43009 처리 완료 (누적 유효 28800개)
# [detail] 28900/43009 처리 완료 (누적 유효 28900개)
# [detail] 29000/43009 처리 완료 (누적 유효 29000개)
# [detail] 29100/43009 처리 완료 (누적 유효 29100개)
# [detail] 29200/43009 처리 완료 (누적 유효 29200개)
# [detail] 29300/43009 처리 완료 (누적 유효 29300개)
# [detail] 29400/43009 처리 완료 (누적 유효 29400개)
# [detail] 29500/43009 처리 완료 (누적 유효 29500개)
# [detail] 29600/43009 처리 완료 (누적 유효 29600개)
# [detail] 29700/43009 처리 완료 (누적 유효 29700개)
# [detail] 29800/43009 처리 완료 (누적 유효 29800개)
# [detail] 29900/43009 처리 완료 (누적 유효 29900개)
# [detail] 30000/43009 처리 완료 (누적 유효 30000개)
# [detail] 30100/43009 처리 완료 (누적 유효 30100개)
# [detail] 30200/43009 처리 완료 (누적 유효 30200개)
# [detail] 30300/43009 처리 완료 (누적 유효 30300개)
# [detail] 30400/43009 처리 완료 (누적 유효 30400개)
# [detail] 30500/43009 처리 완료 (누적 유효 30500개)
# [detail] 30600/43009 처리 완료 (누적 유효 30600개)
# [detail] 30700/43009 처리 완료 (누적 유효 30700개)
# [detail] 30800/43009 처리 완료 (누적 유효 30800개)
# [detail] 30900/43009 처리 완료 (누적 유효 30900개)
# [detail] 31000/43009 처리 완료 (누적 유효 31000개)
# [detail] 31100/43009 처리 완료 (누적 유효 31100개)
# [detail] 31200/43009 처리 완료 (누적 유효 31200개)
# [detail] 31300/43009 처리 완료 (누적 유효 31300개)
# [detail] 31400/43009 처리 완료 (누적 유효 31400개)
# [detail] 31500/43009 처리 완료 (누적 유효 31500개)
# [detail] 31600/43009 처리 완료 (누적 유효 31600개)
# [detail] 31700/43009 처리 완료 (누적 유효 31700개)
# [detail] 31800/43009 처리 완료 (누적 유효 31800개)
# [detail] 31900/43009 처리 완료 (누적 유효 31900개)
# [detail] 32000/43009 처리 완료 (누적 유효 32000개)
# [detail] 32100/43009 처리 완료 (누적 유효 32100개)
# [detail] 32200/43009 처리 완료 (누적 유효 32200개)
# [detail] 32300/43009 처리 완료 (누적 유효 32300개)
# [detail] 32400/43009 처리 완료 (누적 유효 32400개)
# [detail] 32500/43009 처리 완료 (누적 유효 32500개)
# [detail] 32600/43009 처리 완료 (누적 유효 32600개)
# [detail] 32700/43009 처리 완료 (누적 유효 32700개)
# [detail] 32800/43009 처리 완료 (누적 유효 32800개)
# [detail] 32900/43009 처리 완료 (누적 유효 32900개)
# [detail] 33000/43009 처리 완료 (누적 유효 33000개)
# [detail] 33100/43009 처리 완료 (누적 유효 33100개)
# [detail] 33200/43009 처리 완료 (누적 유효 33200개)
# [detail] 33300/43009 처리 완료 (누적 유효 33300개)
# [detail] 33400/43009 처리 완료 (누적 유효 33400개)
# [detail] 33500/43009 처리 완료 (누적 유효 33500개)
# [detail] 33600/43009 처리 완료 (누적 유효 33600개)
# [detail] 33700/43009 처리 완료 (누적 유효 33700개)
# [detail] 33800/43009 처리 완료 (누적 유효 33800개)
# [detail] 33900/43009 처리 완료 (누적 유효 33900개)
# [detail] 34000/43009 처리 완료 (누적 유효 34000개)
# [detail] 34100/43009 처리 완료 (누적 유효 34100개)
# [detail] 34200/43009 처리 완료 (누적 유효 34200개)
# [detail] 34300/43009 처리 완료 (누적 유효 34300개)
# [detail] 34400/43009 처리 완료 (누적 유효 34400개)
# [detail] 34500/43009 처리 완료 (누적 유효 34500개)
# [detail] 34600/43009 처리 완료 (누적 유효 34600개)
# [detail] 34700/43009 처리 완료 (누적 유효 34700개)
# [detail] 34800/43009 처리 완료 (누적 유효 34800개)
# [detail] 34900/43009 처리 완료 (누적 유효 34900개)
# [detail] 35000/43009 처리 완료 (누적 유효 35000개)
# [detail] 35100/43009 처리 완료 (누적 유효 35100개)
# [detail] 35200/43009 처리 완료 (누적 유효 35200개)
# [detail] 35300/43009 처리 완료 (누적 유효 35300개)
# [detail] 35400/43009 처리 완료 (누적 유효 35400개)
# [detail] 35500/43009 처리 완료 (누적 유효 35500개)
# [detail] 35600/43009 처리 완료 (누적 유효 35600개)
# [detail] 35700/43009 처리 완료 (누적 유효 35700개)
# [detail] 35800/43009 처리 완료 (누적 유효 35800개)
# [detail] 35900/43009 처리 완료 (누적 유효 35900개)
# [detail] 36000/43009 처리 완료 (누적 유효 36000개)
# [detail] 36100/43009 처리 완료 (누적 유효 36100개)
# [detail] 36200/43009 처리 완료 (누적 유효 36200개)
# [detail] 36300/43009 처리 완료 (누적 유효 36300개)
# [detail] 36400/43009 처리 완료 (누적 유효 36400개)
# [detail] 36500/43009 처리 완료 (누적 유효 36500개)
# [detail] 36600/43009 처리 완료 (누적 유효 36600개)
# [detail] 36700/43009 처리 완료 (누적 유효 36700개)
# [detail] 36800/43009 처리 완료 (누적 유효 36800개)
# [detail] 36900/43009 처리 완료 (누적 유효 36900개)
# [detail] 37000/43009 처리 완료 (누적 유효 37000개)
# [detail] 37100/43009 처리 완료 (누적 유효 37100개)
# [detail] 37200/43009 처리 완료 (누적 유효 37200개)
# [detail] 37300/43009 처리 완료 (누적 유효 37300개)
# [detail] 37400/43009 처리 완료 (누적 유효 37400개)
# [detail] 37500/43009 처리 완료 (누적 유효 37500개)
# [detail] 37600/43009 처리 완료 (누적 유효 37600개)
# [detail] 37700/43009 처리 완료 (누적 유효 37700개)
# [detail] 37800/43009 처리 완료 (누적 유효 37800개)
# [detail] 37900/43009 처리 완료 (누적 유효 37900개)
# [detail] 38000/43009 처리 완료 (누적 유효 38000개)
# [detail] 38100/43009 처리 완료 (누적 유효 38100개)
# [detail] 38200/43009 처리 완료 (누적 유효 38200개)
# [detail] 38300/43009 처리 완료 (누적 유효 38300개)
# [detail] 38400/43009 처리 완료 (누적 유효 38400개)
# [detail] 38500/43009 처리 완료 (누적 유효 38500개)
# [detail] 38600/43009 처리 완료 (누적 유효 38600개)
# [detail] 38700/43009 처리 완료 (누적 유효 38700개)
# [detail] 38800/43009 처리 완료 (누적 유효 38800개)
# [detail] 38900/43009 처리 완료 (누적 유효 38900개)
# [detail] 39000/43009 처리 완료 (누적 유효 39000개)
# [detail] 39100/43009 처리 완료 (누적 유효 39100개)
# [detail] 39200/43009 처리 완료 (누적 유효 39200개)
# [detail] 39300/43009 처리 완료 (누적 유효 39300개)
# [detail] 39400/43009 처리 완료 (누적 유효 39400개)
# [detail] 39500/43009 처리 완료 (누적 유효 39500개)
# [detail] 39600/43009 처리 완료 (누적 유효 39600개)
# [detail] 39700/43009 처리 완료 (누적 유효 39700개)
# [detail] 39800/43009 처리 완료 (누적 유효 39800개)
# [detail] 39900/43009 처리 완료 (누적 유효 39900개)
# [detail] 40000/43009 처리 완료 (누적 유효 40000개)
# [detail] 40100/43009 처리 완료 (누적 유효 40100개)
# [detail] 40200/43009 처리 완료 (누적 유효 40200개)
# [detail] 40300/43009 처리 완료 (누적 유효 40300개)
# [detail] 40400/43009 처리 완료 (누적 유효 40400개)
# [detail] 40500/43009 처리 완료 (누적 유효 40500개)
# [detail] 40600/43009 처리 완료 (누적 유효 40600개)
# [detail] 40700/43009 처리 완료 (누적 유효 40700개)
# [detail] 40800/43009 처리 완료 (누적 유효 40800개)
# [detail] 40900/43009 처리 완료 (누적 유효 40900개)
# [detail] 41000/43009 처리 완료 (누적 유효 41000개)
# [detail] 41100/43009 처리 완료 (누적 유효 41100개)
# [detail] 41200/43009 처리 완료 (누적 유효 41200개)
# [detail] 41300/43009 처리 완료 (누적 유효 41300개)
# [detail] 41400/43009 처리 완료 (누적 유효 41400개)
# [detail] 41500/43009 처리 완료 (누적 유효 41500개)
# [detail] 41600/43009 처리 완료 (누적 유효 41600개)
# [detail] 41700/43009 처리 완료 (누적 유효 41700개)
# [detail] 41800/43009 처리 완료 (누적 유효 41800개)
# [detail] 41900/43009 처리 완료 (누적 유효 41900개)
# [detail] 42000/43009 처리 완료 (누적 유효 42000개)
# [detail] 42100/43009 처리 완료 (누적 유효 42100개)
# [detail] 42200/43009 처리 완료 (누적 유효 42200개)
# [detail] 42300/43009 처리 완료 (누적 유효 42300개)
# [detail] 42400/43009 처리 완료 (누적 유효 42400개)
# [detail] 42500/43009 처리 완료 (누적 유효 42500개)
# [detail] 42600/43009 처리 완료 (누적 유효 42600개)
# [detail] 42700/43009 처리 완료 (누적 유효 42700개)
# [detail] 42800/43009 처리 완료 (누적 유효 42800개)
# [detail] 42900/43009 처리 완료 (누적 유효 42900개)
# [detail] 43000/43009 처리 완료 (누적 유효 43000개)
# [detail] 43009/43009 처리 완료 (누적 유효 43009개)
# [detail] 최종 유효 레코드 수: 43009
#         id     imdb_id                            title  \
# 0  1179665        None  Solberg, Novo Transe e Resposta
# 1  1441799  tt36933739                  The Echo Forest
# 2  1441820        None                    Unexplainable
# 3  1179664  tt13022120              A Deadly Invitation
# 4  1179685  tt26936594      Everything Had Been Perfect
#
#                     original_title original_language  \
# 0  Solberg, Novo Transe e Resposta                pt
# 1                El Bosque del Eco                es
# 2                    Unexplainable                en
# 3        Invitación a un Asesinato                es
# 4           Alt hadde vært perfekt                no
#
#                                             overview tagline  \
# 0
# 1  Elio, a 16-year-old, decides to venture into t...
# 2  The true story of Gabriel Montenegro, an 8-yea...
# 3  Eccentric millionaire Olivia sends her half si...
# 4  Lotta has only one wish for her birthday - her...
#
#                                  homepage    status release_date  ...  \
# 0                                          Released   2023-05-15  ...
# 1                                          Released   2024-12-14  ...
# 2                                          Released   2024-12-05  ...
# 3  https://www.netflix.com/title/81555681  Released   2023-10-06  ...
# 4                                          Released   2023-01-25  ...
#
#    production_countries   spoken_languages  \
# 0                Brazil          Português
# 1                 Spain            Español
# 2                  None  English|Português
# 3                Mexico            Español
# 4                Norway              Norsk
#
#                                             top_cast  \
# 0                                    Sophia Cantreva
# 1  Domingo C. Ródenas Gómez|Francisco José Abril ...
# 2                                               None
# 3  Regina Blandón|Maribel Verdú|Juan Pablo de San...
# 4           Louise Waage Anda|Nora Aasgaard Egerdahl
#
#                       director  \
# 0              Sophia Cantreva
# 1              Jose A. Morales
# 2                         None
# 3         José Manuel Cravioto
# 4  Mia Sunniva Øveraas Krokaas
#
#                                              writers  \
# 0                                    Sophia Cantreva
# 1                                    Jose A. Morales
# 2                                               None
# 3  Antón de Goenechea|Carmen Posadas|Javier Durán...
# 4                                               None
#
#                                       producers  cast_count  \
# 0                                          None           1
# 1                                          None           3
# 2                                          None           0
# 3  Alexis Fridman|Erik Barmack|Jimena Rodriguez          15
# 4                                          None           2
#
#                   providers_flatrate  providers_rent providers_buy
# 0                               None            None          None
# 1                               None            None          None
# 2                               None            None          None
# 3  Netflix|Netflix Standard with Ads            None          None
# 4                               None            None          None
#
# [5 rows x 35 columns]
# (43009, 35)
# Index(['id', 'imdb_id', 'title', 'original_title', 'original_language',
#        'overview', 'tagline', 'homepage', 'status', 'release_date',
#        'release_year', 'runtime', 'adult', 'budget', 'revenue', 'roi',
#        'vote_count', 'vote_average', 'popularity', 'genres', 'genre_ids',
#        'genre_count', 'keywords', 'keyword_count', 'production_companies',
#        'production_countries', 'spoken_languages', 'top_cast', 'director',
#        'writers', 'producers', 'cast_count', 'providers_flatrate',
#        'providers_rent', 'providers_buy'],
#       dtype='object')
# [main] "tmdb_movies_2023_2025H1_full.csv" 저장 완료

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import os
import time
import math
import requests
from requests.adapters import HTTPAdapter, Retry
from concurrent.futures import ThreadPoolExecutor, as_completed

import pandas as pd
from dotenv import load_dotenv

# .env 에서 TMDB_API_KEY 불러오기
load_dotenv()
TMDB_API_KEY = os.getenv("TMDB_API_KEY")

if not TMDB_API_KEY:
    raise ValueError("TMDB_API_KEY가 설정되지 않았습니다. .env 파일을 확인하세요.")

BASE_URL = "https://api.themoviedb.org/3"

# 세션 + 재시도 설정 (네트워크 에러 대비)
session = requests.Session()
retries = Retry(
    total=5,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504],
)
adapter = HTTPAdapter(max_retries=retries)
session.mount("https://", adapter)
session.mount("http://", adapter)

# %%
def tmdb_get(path, params=None):
    """
    TMDB GET 요청 공통 함수
    - 자동으로 api_key 붙여줌
    - 에러 시 None 리턴
    """
    if params is None:
        params = {}
    params["api_key"] = TMDB_API_KEY
    params.setdefault("language", "en-US")

    url = f"{BASE_URL}{path}"

    try:
        resp = session.get(url, params=params, timeout=10)
        resp.raise_for_status()
        return resp.json()
    except Exception as e:
        print(f"[tmdb_get error] {url} / {e}")
        return None

# %%
def fetch_movies_by_year(year, top_n=500, start_date=None, end_date=None):
    """
    특정 연도(year)에 대해 popularity/vote_count 상위 영화 리스트 조회.
    - TMDB discover/movie 사용
    - 최대 top_n 개까지 가져옴
    """
    results = []
    page = 1
    per_page = 20  # TMDB 한 페이지당 20편

    while len(results) < top_n:
        params = {
            "sort_by": "vote_count.desc",   # 인기순
            "page": page,
            "include_adult": "false",
            "include_video": "false",
        }

        # 기본은 연도만, 필요시 날짜 범위 지정
        if start_date or end_date:
            if start_date:
                params["primary_release_date.gte"] = start_date
            if end_date:
                params["primary_release_date.lte"] = end_date
        else:
            params["primary_release_year"] = year

        data = tmdb_get("/discover/movie", params=params)
        if not data or "results" not in data:
            break

        page_results = data["results"]
        if not page_results:
            break

        for m in page_results:
            results.append(
                {
                    "id": m.get("id"),
                    "title": m.get("title"),
                    "original_title": m.get("original_title"),
                    "original_language": m.get("original_language"),
                    "release_date": m.get("release_date"),
                    "popularity": m.get("popularity"),
                    "vote_count": m.get("vote_count"),
                    "vote_average": m.get("vote_average"),
                    "genre_ids": m.get("genre_ids", []),
                    "adult": m.get("adult"),
                    "video": m.get("video"),
                }
            )
            if len(results) >= top_n:
                break

        total_pages = data.get("total_pages", 1)
        if page >= total_pages:
            break

        page += 1
        time.sleep(0.05)  # discover 쪽 속도 조절 (가벼운 쉬어가기)

    return results[:top_n]

# %%
def fetch_movie_full(movie_id: int):
    """
    한 편의 영화에 대해 상세 정보 수집.
    /movie/{id}?append_to_response=credits,keywords,release_dates 등 사용.
    문제가 생기면 None 리턴.
    """
    params = {
        "append_to_response": "credits,keywords,release_dates"
    }

    data = tmdb_get(f"/movie/{movie_id}", params=params)
    if not data:
        return None

    # 장르 / 제작사 / 나라 / 언어 / 키워드 / 크레딧 등 파싱
    genres = [g.get("name") for g in data.get("genres", [])]
    prod_companies = [c.get("name") for c in data.get("production_companies", [])]
    prod_countries = [c.get("name") for c in data.get("production_countries", [])]
    spoken_languages = [l.get("name") for l in data.get("spoken_languages", [])]

    keywords_block = data.get("keywords", {})
    if isinstance(keywords_block, dict):
        keywords_list = [k.get("name") for k in keywords_block.get("keywords", [])]
    else:
        keywords_list = []

    credits = data.get("credits", {})
    cast_list = credits.get("cast", []) if isinstance(credits, dict) else []
    crew_list = credits.get("crew", []) if isinstance(credits, dict) else []

    # 상위 배우 3명
    top_cast = [c.get("name") for c in cast_list[:3]]
    # 주요 감독(Director)
    directors = [c.get("name") for c in crew_list if c.get("job") == "Director"]

    result = {
        "id": data.get("id"),
        "imdb_id": data.get("imdb_id"),
        "title": data.get("title"),
        "original_title": data.get("original_title"),
        "original_language": data.get("original_language"),
        "overview": data.get("overview"),
        "tagline": data.get("tagline"),
        "status": data.get("status"),
        "release_date": data.get("release_date"),
        "runtime": data.get("runtime"),
        "budget": data.get("budget"),
        "revenue": data.get("revenue"),
        "popularity": data.get("popularity"),
        "vote_count": data.get("vote_count"),
        "vote_average": data.get("vote_average"),
        "adult": data.get("adult"),
        "homepage": data.get("homepage"),
        "genres": genres,
        "production_companies": prod_companies,
        "production_countries": prod_countries,
        "spoken_languages": spoken_languages,
        "keywords": keywords_list,
        "top_cast": top_cast,
        "director": directors[0] if directors else None,
        "all_directors": directors,
    }

    return result

# %%
TOP_N_PER_YEAR = 500

all_list_rows = []

# 2005 ~ 2024
for year in range(2005, 2025):
    print(f"[list] {year}년 수집 시작...")
    movies = fetch_movies_by_year(year, top_n=TOP_N_PER_YEAR)
    for m in movies:
        m["release_year"] = year
    all_list_rows.extend(movies)
    print(f"[list] {year}년 수집 완료: {len(movies)}편")

# 2025년: 1월1일 ~ 11월26일
print("[list] 2025년(부분 기간) 수집 시작...")
movies_2025 = fetch_movies_by_year(
    2025,
    top_n=TOP_N_PER_YEAR,
    start_date="2025-01-01",
    end_date="2025-11-26",
)
for m in movies_2025:
    m["release_year"] = 2025
all_list_rows.extend(movies_2025)
print(f"[list] 2025년 수집 완료: {len(movies_2025)}편")

df_list = pd.DataFrame(all_list_rows)
print("연도별 Top 리스트(중복 포함) 행 수:", len(df_list))

# id 기준 중복 제거
before = len(df_list)
df_list = df_list.drop_duplicates(subset=["id"])
after = len(df_list)
print(f"id 기준 중복 제거: {before} → {after}")

df_list[["id", "title", "release_date", "release_year", "popularity"]].head()
# Out:
# [list] 2005년 수집 시작...
# [list] 2005년 수집 완료: 500편
# [list] 2006년 수집 시작...
# [list] 2006년 수집 완료: 500편
# [list] 2007년 수집 시작...
# [list] 2007년 수집 완료: 500편
# [list] 2008년 수집 시작...
# [list] 2008년 수집 완료: 500편
# [list] 2009년 수집 시작...
# [list] 2009년 수집 완료: 500편
# [list] 2010년 수집 시작...
# [list] 2010년 수집 완료: 500편
# [list] 2011년 수집 시작...
# [list] 2011년 수집 완료: 500편
# [list] 2012년 수집 시작...
# [list] 2012년 수집 완료: 500편
# [list] 2013년 수집 시작...
# [list] 2013년 수집 완료: 500편
# [list] 2014년 수집 시작...
# [list] 2014년 수집 완료: 500편
# [list] 2015년 수집 시작...
# [list] 2015년 수집 완료: 500편
# [list] 2016년 수집 시작...
# [list] 2016년 수집 완료: 500편
# [list] 2017년 수집 시작...
# [list] 2017년 수집 완료: 500편
# [list] 2018년 수집 시작...
# [list] 2018년 수집 완료: 500편
# [list] 2019년 수집 시작...
# [list] 2019년 수집 완료: 500편
# [list] 2020년 수집 시작...
# [list] 2020년 수집 완료: 500편
# [list] 2021년 수집 시작...
# [list] 2021년 수집 완료: 500편
# [list] 2022년 수집 시작...
# [list] 2022년 수집 완료: 500편
# [list] 2023년 수집 시작...
# [list] 2023년 수집 완료: 500편
# [list] 2024년 수집 시작...
# [list] 2024년 수집 완료: 500편
# [list] 2025년(부분 기간) 수집 시작...
# [list] 2025년 수집 완료: 500편
# 연도별 Top 리스트(중복 포함) 행 수: 10500
# id 기준 중복 제거: 10500 → 10500
#      id                                         title release_date  \
# 0   272                                 Batman Begins   2005-06-10
# 1   674           Harry Potter and the Goblet of Fire   2005-11-16
# 2   118             Charlie and the Chocolate Factory   2005-07-13
# 3  1895  Star Wars: Episode III - Revenge of the Sith   2005-05-17
# 4   953                                    Madagascar   2005-05-25
#
#    release_year  popularity
# 0          2005     14.3261
# 1          2005     23.2812
# 2          2005     14.6816
# 3          2005     10.4083
# 4          2005     14.5757

# %%
movie_ids = df_list["id"].astype(int).tolist()

detail_rows = []
total = len(movie_ids)
start = time.time()

def fetch_one(mid):
    """
    멀티스레드에서 쓸 래퍼 함수
    - 에러 나면 None 리턴
    """
    try:
        return fetch_movie_full(mid)
    except Exception as e:
        print(f"[error] id={mid}, {e}")
        return None

# TMDB 레이트리밋 고려해서 4~6 정도가 안전
MAX_WORKERS = 5

print(f"[detail] 전체 대상 편수: {total}, 워커 수: {MAX_WORKERS}")

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    future_to_id = {executor.submit(fetch_one, mid): mid for mid in movie_ids}

    for i, future in enumerate(as_completed(future_to_id), start=1):
        result = future.result()
        if result is not None:
            detail_rows.append(result)

        if i % 50 == 0 or i == total:
            elapsed = time.time() - start
            print(
                f"[detail] {i} / {total} 편 처리 완료 "
                f"(경과 {elapsed/60:.1f}분)"
            )

df_detail = pd.DataFrame(detail_rows)
print("상세정보 수집 행 수:", len(df_detail))
df_detail.head()
# Out:
# [detail] 전체 대상 편수: 10500, 워커 수: 5
# [detail] 50 / 10500 편 처리 완료 (경과 0.1분)
# [detail] 100 / 10500 편 처리 완료 (경과 0.1분)
# [detail] 150 / 10500 편 처리 완료 (경과 0.1분)
# [detail] 200 / 10500 편 처리 완료 (경과 0.2분)
# [detail] 250 / 10500 편 처리 완료 (경과 0.2분)
# [detail] 300 / 10500 편 처리 완료 (경과 0.3분)
# [detail] 350 / 10500 편 처리 완료 (경과 0.3분)
# [detail] 400 / 10500 편 처리 완료 (경과 0.3분)
# [detail] 450 / 10500 편 처리 완료 (경과 0.4분)
# [detail] 500 / 10500 편 처리 완료 (경과 0.4분)
# [detail] 550 / 10500 편 처리 완료 (경과 0.5분)
# [detail] 600 / 10500 편 처리 완료 (경과 0.5분)
# [detail] 650 / 10500 편 처리 완료 (경과 0.6분)
# [detail] 700 / 10500 편 처리 완료 (경과 0.6분)
# [detail] 750 / 10500 편 처리 완료 (경과 0.6분)
# [detail] 800 / 10500 편 처리 완료 (경과 0.7분)
# [detail] 850 / 10500 편 처리 완료 (경과 0.7분)
# [detail] 900 / 10500 편 처리 완료 (경과 0.8분)
# [detail] 950 / 10500 편 처리 완료 (경과 0.8분)
# [detail] 1000 / 10500 편 처리 완료 (경과 0.8분)
# [detail] 1050 / 10500 편 처리 완료 (경과 0.9분)
# [detail] 1100 / 10500 편 처리 완료 (경과 0.9분)
# [detail] 1150 / 10500 편 처리 완료 (경과 1.0분)
# [detail] 1200 / 10500 편 처리 완료 (경과 1.0분)
# [detail] 1250 / 10500 편 처리 완료 (경과 1.0분)
# [detail] 1300 / 10500 편 처리 완료 (경과 1.1분)
# [detail] 1350 / 10500 편 처리 완료 (경과 1.1분)
# [detail] 1400 / 10500 편 처리 완료 (경과 1.2분)
# [detail] 1450 / 10500 편 처리 완료 (경과 1.2분)
# [detail] 1500 / 10500 편 처리 완료 (경과 1.2분)
# [detail] 1550 / 10500 편 처리 완료 (경과 1.3분)
# [detail] 1600 / 10500 편 처리 완료 (경과 1.3분)
# [detail] 1650 / 10500 편 처리 완료 (경과 1.4분)
# [detail] 1700 / 10500 편 처리 완료 (경과 1.4분)
# [detail] 1750 / 10500 편 처리 완료 (경과 1.5분)
# [detail] 1800 / 10500 편 처리 완료 (경과 1.5분)
# [detail] 1850 / 10500 편 처리 완료 (경과 1.5분)
# [detail] 1900 / 10500 편 처리 완료 (경과 1.6분)
# [detail] 1950 / 10500 편 처리 완료 (경과 1.6분)
# [detail] 2000 / 10500 편 처리 완료 (경과 1.7분)
# [detail] 2050 / 10500 편 처리 완료 (경과 1.7분)
# [detail] 2100 / 10500 편 처리 완료 (경과 1.7분)
# [detail] 2150 / 10500 편 처리 완료 (경과 1.8분)
# [detail] 2200 / 10500 편 처리 완료 (경과 1.8분)
# [detail] 2250 / 10500 편 처리 완료 (경과 1.9분)
# [detail] 2300 / 10500 편 처리 완료 (경과 1.9분)
# [detail] 2350 / 10500 편 처리 완료 (경과 2.0분)
# [detail] 2400 / 10500 편 처리 완료 (경과 2.0분)
# [detail] 2450 / 10500 편 처리 완료 (경과 2.0분)
# [detail] 2500 / 10500 편 처리 완료 (경과 2.1분)
# [detail] 2550 / 10500 편 처리 완료 (경과 2.1분)
# [detail] 2600 / 10500 편 처리 완료 (경과 2.2분)
# [detail] 2650 / 10500 편 처리 완료 (경과 2.2분)
# [detail] 2700 / 10500 편 처리 완료 (경과 2.2분)
# [detail] 2750 / 10500 편 처리 완료 (경과 2.3분)
# [detail] 2800 / 10500 편 처리 완료 (경과 2.3분)
# [detail] 2850 / 10500 편 처리 완료 (경과 2.4분)
# [detail] 2900 / 10500 편 처리 완료 (경과 2.4분)
# [detail] 2950 / 10500 편 처리 완료 (경과 2.5분)
# [detail] 3000 / 10500 편 처리 완료 (경과 2.5분)
# [detail] 3050 / 10500 편 처리 완료 (경과 2.5분)
# [detail] 3100 / 10500 편 처리 완료 (경과 2.6분)
# [detail] 3150 / 10500 편 처리 완료 (경과 2.6분)
# [detail] 3200 / 10500 편 처리 완료 (경과 2.7분)
# [detail] 3250 / 10500 편 처리 완료 (경과 2.7분)
# [detail] 3300 / 10500 편 처리 완료 (경과 2.7분)
# [detail] 3350 / 10500 편 처리 완료 (경과 2.8분)
# [detail] 3400 / 10500 편 처리 완료 (경과 2.8분)
# [detail] 3450 / 10500 편 처리 완료 (경과 2.9분)
# [detail] 3500 / 10500 편 처리 완료 (경과 2.9분)
# [detail] 3550 / 10500 편 처리 완료 (경과 2.9분)
# [detail] 3600 / 10500 편 처리 완료 (경과 3.0분)
# [detail] 3650 / 10500 편 처리 완료 (경과 3.0분)
# [detail] 3700 / 10500 편 처리 완료 (경과 3.1분)
# [detail] 3750 / 10500 편 처리 완료 (경과 3.1분)
# [detail] 3800 / 10500 편 처리 완료 (경과 3.2분)
# [detail] 3850 / 10500 편 처리 완료 (경과 3.2분)
# [detail] 3900 / 10500 편 처리 완료 (경과 3.2분)
# [detail] 3950 / 10500 편 처리 완료 (경과 3.3분)
# [detail] 4000 / 10500 편 처리 완료 (경과 3.3분)
# [detail] 4050 / 10500 편 처리 완료 (경과 3.4분)
# [detail] 4100 / 10500 편 처리 완료 (경과 3.4분)
# [detail] 4150 / 10500 편 처리 완료 (경과 3.5분)
# [detail] 4200 / 10500 편 처리 완료 (경과 3.5분)
# [detail] 4250 / 10500 편 처리 완료 (경과 3.5분)
# [detail] 4300 / 10500 편 처리 완료 (경과 3.6분)
# [detail] 4350 / 10500 편 처리 완료 (경과 3.6분)
# [detail] 4400 / 10500 편 처리 완료 (경과 3.7분)
# [detail] 4450 / 10500 편 처리 완료 (경과 3.7분)
# [detail] 4500 / 10500 편 처리 완료 (경과 3.7분)
# [detail] 4550 / 10500 편 처리 완료 (경과 3.8분)
# [detail] 4600 / 10500 편 처리 완료 (경과 3.8분)
# [detail] 4650 / 10500 편 처리 완료 (경과 3.9분)
# [detail] 4700 / 10500 편 처리 완료 (경과 3.9분)
# [detail] 4750 / 10500 편 처리 완료 (경과 4.0분)
# [detail] 4800 / 10500 편 처리 완료 (경과 4.0분)
# [detail] 4850 / 10500 편 처리 완료 (경과 4.0분)
# [detail] 4900 / 10500 편 처리 완료 (경과 4.1분)
# [detail] 4950 / 10500 편 처리 완료 (경과 4.1분)
# [detail] 5000 / 10500 편 처리 완료 (경과 4.2분)
# [detail] 5050 / 10500 편 처리 완료 (경과 4.2분)
# [detail] 5100 / 10500 편 처리 완료 (경과 4.2분)
# [detail] 5150 / 10500 편 처리 완료 (경과 4.3분)
# [detail] 5200 / 10500 편 처리 완료 (경과 4.3분)
# [detail] 5250 / 10500 편 처리 완료 (경과 4.4분)
# [detail] 5300 / 10500 편 처리 완료 (경과 4.4분)
# [detail] 5350 / 10500 편 처리 완료 (경과 4.5분)
# [detail] 5400 / 10500 편 처리 완료 (경과 4.5분)
# [detail] 5450 / 10500 편 처리 완료 (경과 4.5분)
# [detail] 5500 / 10500 편 처리 완료 (경과 4.6분)
# [detail] 5550 / 10500 편 처리 완료 (경과 4.6분)
# [detail] 5600 / 10500 편 처리 완료 (경과 4.7분)
# [detail] 5650 / 10500 편 처리 완료 (경과 4.7분)
# [detail] 5700 / 10500 편 처리 완료 (경과 4.7분)
# [detail] 5750 / 10500 편 처리 완료 (경과 4.8분)
# [detail] 5800 / 10500 편 처리 완료 (경과 4.8분)
# [detail] 5850 / 10500 편 처리 완료 (경과 4.9분)
# [detail] 5900 / 10500 편 처리 완료 (경과 4.9분)
# [detail] 5950 / 10500 편 처리 완료 (경과 4.9분)
# [detail] 6000 / 10500 편 처리 완료 (경과 5.0분)
# [detail] 6050 / 10500 편 처리 완료 (경과 5.0분)
# [detail] 6100 / 10500 편 처리 완료 (경과 5.1분)
# [detail] 6150 / 10500 편 처리 완료 (경과 5.1분)
# [detail] 6200 / 10500 편 처리 완료 (경과 5.2분)
# [detail] 6250 / 10500 편 처리 완료 (경과 5.2분)
# [detail] 6300 / 10500 편 처리 완료 (경과 5.2분)
# [detail] 6350 / 10500 편 처리 완료 (경과 5.3분)
# [detail] 6400 / 10500 편 처리 완료 (경과 5.3분)
# [detail] 6450 / 10500 편 처리 완료 (경과 5.4분)
# [detail] 6500 / 10500 편 처리 완료 (경과 5.4분)
# [detail] 6550 / 10500 편 처리 완료 (경과 5.4분)
# [detail] 6600 / 10500 편 처리 완료 (경과 5.5분)
# [detail] 6650 / 10500 편 처리 완료 (경과 5.5분)
# [detail] 6700 / 10500 편 처리 완료 (경과 5.6분)
# [detail] 6750 / 10500 편 처리 완료 (경과 5.6분)
# [detail] 6800 / 10500 편 처리 완료 (경과 5.7분)
# [detail] 6850 / 10500 편 처리 완료 (경과 5.7분)
# [detail] 6900 / 10500 편 처리 완료 (경과 5.7분)
# [detail] 6950 / 10500 편 처리 완료 (경과 5.8분)
# [detail] 7000 / 10500 편 처리 완료 (경과 5.8분)
# [detail] 7050 / 10500 편 처리 완료 (경과 5.9분)
# [detail] 7100 / 10500 편 처리 완료 (경과 5.9분)
# [detail] 7150 / 10500 편 처리 완료 (경과 5.9분)
# [detail] 7200 / 10500 편 처리 완료 (경과 6.0분)
# [detail] 7250 / 10500 편 처리 완료 (경과 6.0분)
# [detail] 7300 / 10500 편 처리 완료 (경과 6.1분)
# [detail] 7350 / 10500 편 처리 완료 (경과 6.1분)
# [detail] 7400 / 10500 편 처리 완료 (경과 6.2분)
# [detail] 7450 / 10500 편 처리 완료 (경과 6.2분)
# [detail] 7500 / 10500 편 처리 완료 (경과 6.2분)
# [detail] 7550 / 10500 편 처리 완료 (경과 6.3분)
# [detail] 7600 / 10500 편 처리 완료 (경과 6.3분)
# [detail] 7650 / 10500 편 처리 완료 (경과 6.4분)
# [detail] 7700 / 10500 편 처리 완료 (경과 6.4분)
# [detail] 7750 / 10500 편 처리 완료 (경과 6.4분)
# [detail] 7800 / 10500 편 처리 완료 (경과 6.5분)
# [detail] 7850 / 10500 편 처리 완료 (경과 6.5분)
# [detail] 7900 / 10500 편 처리 완료 (경과 6.6분)
# [detail] 7950 / 10500 편 처리 완료 (경과 6.6분)
# [detail] 8000 / 10500 편 처리 완료 (경과 6.7분)
# [detail] 8050 / 10500 편 처리 완료 (경과 6.7분)
# [detail] 8100 / 10500 편 처리 완료 (경과 6.7분)
# [detail] 8150 / 10500 편 처리 완료 (경과 6.8분)
# [detail] 8200 / 10500 편 처리 완료 (경과 6.8분)
# [detail] 8250 / 10500 편 처리 완료 (경과 6.9분)
# [detail] 8300 / 10500 편 처리 완료 (경과 6.9분)
# [detail] 8350 / 10500 편 처리 완료 (경과 6.9분)
# [detail] 8400 / 10500 편 처리 완료 (경과 7.0분)
# [detail] 8450 / 10500 편 처리 완료 (경과 7.0분)
# [detail] 8500 / 10500 편 처리 완료 (경과 7.1분)
# [detail] 8550 / 10500 편 처리 완료 (경과 7.1분)
# [detail] 8600 / 10500 편 처리 완료 (경과 7.2분)
# [detail] 8650 / 10500 편 처리 완료 (경과 7.2분)
# [detail] 8700 / 10500 편 처리 완료 (경과 7.2분)
# [detail] 8750 / 10500 편 처리 완료 (경과 7.3분)
# [detail] 8800 / 10500 편 처리 완료 (경과 7.3분)
# [detail] 8850 / 10500 편 처리 완료 (경과 7.4분)
# [detail] 8900 / 10500 편 처리 완료 (경과 7.4분)
# [detail] 8950 / 10500 편 처리 완료 (경과 7.4분)
# [detail] 9000 / 10500 편 처리 완료 (경과 7.5분)
# [detail] 9050 / 10500 편 처리 완료 (경과 7.5분)
# [detail] 9100 / 10500 편 처리 완료 (경과 7.6분)
# [detail] 9150 / 10500 편 처리 완료 (경과 7.6분)
# [detail] 9200 / 10500 편 처리 완료 (경과 7.7분)
# [detail] 9250 / 10500 편 처리 완료 (경과 7.7분)
# [detail] 9300 / 10500 편 처리 완료 (경과 7.7분)
# [detail] 9350 / 10500 편 처리 완료 (경과 7.8분)
# [detail] 9400 / 10500 편 처리 완료 (경과 7.8분)
# [detail] 9450 / 10500 편 처리 완료 (경과 7.9분)
# [detail] 9500 / 10500 편 처리 완료 (경과 7.9분)
# [detail] 9550 / 10500 편 처리 완료 (경과 7.9분)
# [detail] 9600 / 10500 편 처리 완료 (경과 8.0분)
# [detail] 9650 / 10500 편 처리 완료 (경과 8.0분)
# [detail] 9700 / 10500 편 처리 완료 (경과 8.1분)
# [detail] 9750 / 10500 편 처리 완료 (경과 8.1분)
# [detail] 9800 / 10500 편 처리 완료 (경과 8.2분)
# [detail] 9850 / 10500 편 처리 완료 (경과 8.2분)
# [detail] 9900 / 10500 편 처리 완료 (경과 8.2분)
# [detail] 9950 / 10500 편 처리 완료 (경과 8.3분)
# [detail] 10000 / 10500 편 처리 완료 (경과 8.3분)
# [detail] 10050 / 10500 편 처리 완료 (경과 8.4분)
# [detail] 10100 / 10500 편 처리 완료 (경과 8.4분)
# [detail] 10150 / 10500 편 처리 완료 (경과 8.4분)
# [detail] 10200 / 10500 편 처리 완료 (경과 8.5분)
# [detail] 10250 / 10500 편 처리 완료 (경과 8.5분)
# [detail] 10300 / 10500 편 처리 완료 (경과 8.6분)
# [detail] 10350 / 10500 편 처리 완료 (경과 8.6분)
# [detail] 10400 / 10500 편 처리 완료 (경과 8.6분)
# [detail] 10450 / 10500 편 처리 완료 (경과 8.7분)
# [detail] 10500 / 10500 편 처리 완료 (경과 8.7분)
# 상세정보 수집 행 수: 10500
#      id    imdb_id                                              title  \
# 0   272  tt0372784                                      Batman Begins
# 1   411  tt0363771  The Chronicles of Narnia: The Lion, the Witch ...
# 2  1895  tt0121766       Star Wars: Episode III - Revenge of the Sith
# 3   118  tt0367594                  Charlie and the Chocolate Factory
# 4   953  tt0351283                                         Madagascar
#
#                                       original_title original_language  \
# 0                                      Batman Begins                en
# 1  The Chronicles of Narnia: The Lion, the Witch ...                en
# 2       Star Wars: Episode III - Revenge of the Sith                en
# 3                  Charlie and the Chocolate Factory                en
# 4                                         Madagascar                en
#
#                                             overview  \
# 0  Driven by tragedy, billionaire Bruce Wayne ded...
# 1  Siblings Lucy, Edmund, Susan and Peter step th...
# 2  The evil Darth Sidious enacts his final plan f...
# 3  A young boy wins a tour through the most magni...
# 4  Four animal friends get a taste of the wild li...
#
#                                              tagline    status release_date  \
# 0                             Evil fears the knight.  Released   2005-06-10
# 1             The beloved masterpiece comes to life.  Released   2005-12-07
# 2  Fear leads to anger. Anger leads to hate. Hate...  Released   2005-05-17
# 3                  Prepare for a taste of adventure.  Released   2005-07-13
# 4  They weren't born in the wild... They were shi...  Released   2005-05-25
#
#    runtime  ...  adult                                           homepage  \
# 0      140  ...  False   https://www.warnerbros.com/movies/batman-begins/
# 1      143  ...  False
# 2      140  ...  False  http://www.starwars.com/films/star-wars-episod...
# 3      115  ...  False  https://www.warnerbros.com/charlie-and-chocola...
# 4       86  ...  False       https://www.dreamworks.com/movies/madagascar
#
#                                    genres  \
# 0                  [Drama, Crime, Action]
# 1            [Adventure, Family, Fantasy]
# 2    [Adventure, Action, Science Fiction]
# 3    [Adventure, Comedy, Family, Fantasy]
# 4  [Family, Animation, Adventure, Comedy]
#
#                                 production_companies  \
# 0  [Warner Bros. Pictures, DC, Syncopy, Legendary...
# 1  [Walt Disney Pictures, Walden Media, C.S. Lewi...
# 2                                   [Lucasfilm Ltd.]
# 3  [Warner Bros. Pictures, Village Roadshow Pictu...
# 4        [Pacific Data Images, DreamWorks Animation]
#
#                          production_countries  \
# 0  [United Kingdom, United States of America]
# 1  [United Kingdom, United States of America]
# 2                  [United States of America]
# 3  [United Kingdom, United States of America]
# 4                  [United States of America]
#
#                                    spoken_languages  \
# 0                              [English, اردو, 普通话]
# 1                                [English, Deutsch]
# 2                                         [English]
# 3                                         [English]
# 4  [English, Français, Deutsch, Português, Español]
#
#                                             keywords  \
# 0  [martial arts, undercover, loss of loved one, ...
# 1  [witch, sibling relationship, saving the world...
# 2  [showdown, lava, fight, politics, volcano, cho...
# 3  [factory worker, london, england, based on nov...
# 4  [friendship, island, escape, africa, lion, zoo...
#
#                                             top_cast           director  \
# 0       [Christian Bale, Michael Caine, Liam Neeson]  Christopher Nolan
# 1  [William Moseley, Anna Popplewell, Skandar Key...     Andrew Adamson
# 2  [Hayden Christensen, Ewan McGregor, Natalie Po...       George Lucas
# 3       [Johnny Depp, Freddie Highmore, David Kelly]         Tim Burton
# 4         [Ben Stiller, Chris Rock, David Schwimmer]       Eric Darnell
#
#                  all_directors
# 0          [Christopher Nolan]
# 1             [Andrew Adamson]
# 2               [George Lucas]
# 3                 [Tim Burton]
# 4  [Eric Darnell, Tom McGrath]
#
# [5 rows x 25 columns]

# %%
# df_list 에는 release_year, 기본 리스트 정보가 있고
# df_detail 에는 상세 정보가 있음
# id 기준으로 left merge

df_final = pd.merge(
    df_detail,
    df_list[["id", "release_year", "title", "original_title", "popularity", "vote_count", "vote_average"]],
    on="id",
    how="left",
    suffixes=("_detail", "_list")
)

print("최종 데이터프레임 행/열:", df_final.shape)
df_final.head()

# CSV 저장 (파일명은 캔이 원하는대로 변경 가능)
output_path = "tmdb_top500_per_year_full_2005_2025.csv"
df_final.to_csv(output_path, index=False, encoding="utf-8-sig")
print("저장 완료:", output_path)
# Out:
# 최종 데이터프레임 행/열: (10500, 31)
# 저장 완료: tmdb_top500_per_year_full_2005_2025.csv

# %%
df_final[(df_final['revenue'] > 1)&(df_final['budget']>1)].shape
# Out:
# (4533, 31)

# %%
df_final
# Out:
#             id     imdb_id                                       title_detail  \
# 0          272   tt0372784                                      Batman Begins
# 1          411   tt0363771  The Chronicles of Narnia: The Lion, the Witch ...
# 2         1895   tt0121766       Star Wars: Episode III - Revenge of the Sith
# 3          118   tt0367594                  Charlie and the Chocolate Factory
# 4          953   tt0351283                                         Madagascar
# ...        ...         ...                                                ...
# 10495  1429738  tt35669044                            Tee Yai: Born to Be Bad
# 10496  1313229  tt35519445                                               Nino
# 10497  1313003  tt32478708                                        Close To Me
# 10498  1309410  tt35404638                                       100 Million!
# 10499  1261504  tt34208307                                             Faster
#
#                                    original_title_detail original_language  \
# 0                                          Batman Begins                en
# 1      The Chronicles of Narnia: The Lion, the Witch ...                en
# 2           Star Wars: Episode III - Revenge of the Sith                en
# 3                      Charlie and the Chocolate Factory                en
# 4                                             Madagascar                en
# ...                                                  ...               ...
# 10495                                 ตี๋ใหญ่ ฤกษ์ดาวโจร                th
# 10496                                               Nino                fr
# 10497                                       Muori di lei                it
# 10498                                     100 Millions !                fr
# 10499                                             Rapide                fr
#
#                                                 overview  \
# 0      Driven by tragedy, billionaire Bruce Wayne ded...
# 1      Siblings Lucy, Edmund, Susan and Peter step th...
# 2      The evil Darth Sidious enacts his final plan f...
# 3      A young boy wins a tour through the most magni...
# 4      Four animal friends get a taste of the wild li...
# ...                                                  ...
# 10495  In 1980s Bangkok, a wily thief stages a series...
# 10496  Nino is a young man on a journey to reconnect ...
# 10497  Luca is a forty-year-old teacher experiencing ...
# 10498  A printing house worker and union leader inher...
# 10499  A former racer returns to the sport through a ...
#
#                                                  tagline    status  \
# 0                                 Evil fears the knight.  Released
# 1                 The beloved masterpiece comes to life.  Released
# 2      Fear leads to anger. Anger leads to hate. Hate...  Released
# 3                      Prepare for a taste of adventure.  Released
# 4      They weren't born in the wild... They were shi...  Released
# ...                                                  ...       ...
# 10495  Meet the "King of Thieves", whose life is comi...  Released
# 10496                                                     Released
# 10497                                                     Released
# 10498                                                     Released
# 10499                                                     Released
#
#       release_date  runtime  ...  \
# 0       2005-06-10      140  ...
# 1       2005-12-07      143  ...
# 2       2005-05-17      140  ...
# 3       2005-07-13      115  ...
# 4       2005-05-25       86  ...
# ...            ...      ...  ...
# 10495   2025-11-12      117  ...
# 10496   2025-09-17       96  ...
# 10497   2025-03-20      103  ...
# 10498   2025-03-26       97  ...
# 10499   2025-04-16       98  ...
#
#                                                 keywords  \
# 0      [martial arts, undercover, loss of loved one, ...
# 1      [witch, sibling relationship, saving the world...
# 2      [showdown, lava, fight, politics, volcano, cho...
# 3      [factory worker, london, england, based on nov...
# 4      [friendship, island, escape, africa, lion, zoo...
# ...                                                  ...
# 10495                                                 []
# 10496          [paris, france, cancer, paris, radiology]
# 10497                                                 []
# 10498                                                 []
# 10499                                                 []
#
#                                                 top_cast            director  \
# 0           [Christian Bale, Michael Caine, Liam Neeson]   Christopher Nolan
# 1      [William Moseley, Anna Popplewell, Skandar Key...      Andrew Adamson
# 2      [Hayden Christensen, Ewan McGregor, Natalie Po...        George Lucas
# 3           [Johnny Depp, Freddie Highmore, David Kelly]          Tim Burton
# 4             [Ben Stiller, Chris Rock, David Schwimmer]        Eric Darnell
# ...                                                  ...                 ...
# 10495  [Nattawin Wattanagitiphat, Witsarut Himmarat, ...     Nonzee Nimibutr
# 10496  [Théodore Pellerin, Salomé Dewaels, Jeanne Bal...      Pauline Loquès
# 10497  [Riccardo Scamarcio, Mariela Garriga, Maria Ch...       Stefano Sardo
# 10498       [Kad Merad, Michèle Laroque, Martin Karmann]         Nath Dumont
# 10499      [Paola Locatelli, Alban Lenoir, Anne Marivin]  Morgan S. Dalibert
#
#                      all_directors  release_year  \
# 0              [Christopher Nolan]          2005
# 1                 [Andrew Adamson]          2005
# 2                   [George Lucas]          2005
# 3                     [Tim Burton]          2005
# 4      [Eric Darnell, Tom McGrath]          2005
# ...                            ...           ...
# 10495            [Nonzee Nimibutr]          2025
# 10496             [Pauline Loquès]          2025
# 10497              [Stefano Sardo]          2025
# 10498                [Nath Dumont]          2025
# 10499         [Morgan S. Dalibert]          2025
#
#                                               title_list  \
# 0                                          Batman Begins
# 1      The Chronicles of Narnia: The Lion, the Witch ...
# 2           Star Wars: Episode III - Revenge of the Sith
# 3                      Charlie and the Chocolate Factory
# 4                                             Madagascar
# ...                                                  ...
# 10495                            Tee Yai: Born to Be Bad
# 10496                                               Nino
# 10497                                        Close To Me
# 10498                                       100 Million!
# 10499                                             Faster
#
#                                      original_title_list popularity_list  \
# 0                                          Batman Begins         14.3261
# 1      The Chronicles of Narnia: The Lion, the Witch ...         19.6752
# 2           Star Wars: Episode III - Revenge of the Sith         10.4083
# 3                      Charlie and the Chocolate Factory         14.6816
# 4                                             Madagascar         14.5757
# ...                                                  ...             ...
# 10495                                 ตี๋ใหญ่ ฤกษ์ดาวโจร         66.4793
# 10496                                               Nino          4.6970
# 10497                                       Muori di lei          3.4445
# 10498                                     100 Millions !          2.1742
# 10499                                             Rapide          6.7653
#
#       vote_count_list vote_average_list
# 0               21981             7.718
# 1               11165             7.100
# 2               14480             7.455
# 3               15763             7.040
# 4               11368             6.916
# ...               ...               ...
# 10495              35             4.800
# 10496              35             7.429
# 10497              35             5.686
# 10498              35             4.257
# 10499              35             5.900
#
# [10500 rows x 31 columns]
